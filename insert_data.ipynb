# %%
import pyspark.sql

spark.sql("""
INSERT INTO organization.employee_events VALUES
(1,'Alice','HR',50000,'HIRED','2020-01-10 09:00','HR_SYS'),
(1,'Alice','HR',55000,'SALARY_CHANGE','2021-02-01 10:00','HR_SYS'),
(1,'Alice','SALES',55000,'DEPT_CHANGE','2022-01-15 12:00','CRM'),
(2,'Bob','TECH',NULL,'HIRED','2019-03-15 09:30','HR_SYS'),
(2,'Bob','TECH',60000,'SALARY_CHANGE','2020-04-01 11:00','PAYROLL'),
(2,'Bob','TECH',58000,'SALARY_CHANGE','2019-12-01 08:00','PAYROLL'),
(3,'Charlie','SALES',70000,'HIRED','2018-07-01 09:00','HR_SYS'),
(3,'Charlie','SALES',NULL,'TERMINATED','2023-01-01 00:00','HR_SYS');
"""
)

spark.sql("""
INSERT INTO organization.department VALUES
('HR','Delhi','2018-01-01'),
('HR','Gurgaon','2022-01-01'),
('SALES','Mumbai','2017-01-01'),
('TECH','Bangalore','2016-01-01')
"""
)

spark.sql(
"""
INSERT INTO organization.pipeline_runs VALUES
(1,'2025-01-01 09:00'),
(2,'2025-01-02 09:00'),
(3,'2025-01-03 09:00');
"""
)
